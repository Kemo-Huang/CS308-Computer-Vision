# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True (the environment provided does
# not support GPUs and we will not provide any support for GPU
# computation in this project). Please note that 
# we will evaluate your implementations only using CPU mode so even if
# you use a GPU, make sure your code runs in the CPU mode with the
# environment we provided. 
use_GPU = True
if use_GPU:
    from utils_gpu import *

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. **Dataset** - an object which can load the data and labels given an index.
# 2. **Model** - an object that contains the network architecture definition.
# 3. **Loss function** - a function that measures how far the network output is from the ground truth label.
# 4. **Optimizer** - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 1e-2  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# Now you will modify the create_datasets function from student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will also add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should achieve an accuracy of at least **50%**. Make sure your network passes this threshold--it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(48, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1536, out_features=1024, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.8, inplace=False)
#     (3): Linear(in_features=1024, out_features=15, bias=True)
#   )
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is ', out.size())
# Out:
# Network output size is  torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since we will not be using the notebook you submit to evaluate.

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# Setting up a new session...
# ---------------------------------------
# Experiment: part1
# n_epochs: 100
# batch_size: 50
# do_val: True
# shuffle: True
# num_workers: 4
# val_freq: 1
# print_freq: 100
# experiment: part1
# checkpoint_file: None
# resume_optim: True
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.716, top-1 accuracy 10.000, top-5 accuracy 24.000
# train part1: loss 2.660641
# val part1: batch 0/59, loss 2.453, top-1 accuracy 10.000, top-5 accuracy 48.000
# val part1: loss 2.674087
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.418, top-1 accuracy 16.000, top-5 accuracy 64.000
# train part1: loss 2.474717
# val part1: batch 0/59, loss 2.351, top-1 accuracy 22.000, top-5 accuracy 70.000
# val part1: loss 2.311414
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.262, top-1 accuracy 28.000, top-5 accuracy 68.000
# train part1: loss 2.332324
# val part1: batch 0/59, loss 2.624, top-1 accuracy 22.000, top-5 accuracy 48.000
# val part1: loss 2.108762
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.374, top-1 accuracy 24.000, top-5 accuracy 66.000
# train part1: loss 2.277820
# val part1: batch 0/59, loss 2.299, top-1 accuracy 30.000, top-5 accuracy 66.000
# val part1: loss 2.034218
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 2.404, top-1 accuracy 28.000, top-5 accuracy 62.000
# train part1: loss 2.246646
# val part1: batch 0/59, loss 2.203, top-1 accuracy 2.000, top-5 accuracy 90.000
# val part1: loss 2.223471
# Checkpoint saved
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 2.088, top-1 accuracy 38.000, top-5 accuracy 82.000
# train part1: loss 2.194817
# val part1: batch 0/59, loss 2.883, top-1 accuracy 6.000, top-5 accuracy 40.000
# val part1: loss 2.443704
# Checkpoint saved
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 2.317, top-1 accuracy 24.000, top-5 accuracy 70.000
# train part1: loss 2.188513
# val part1: batch 0/59, loss 2.388, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 2.040629
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 2.052, top-1 accuracy 30.000, top-5 accuracy 78.000
# train part1: loss 2.090109
# val part1: batch 0/59, loss 2.429, top-1 accuracy 10.000, top-5 accuracy 66.000
# val part1: loss 1.852616
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 2.074, top-1 accuracy 34.000, top-5 accuracy 72.000
# train part1: loss 2.022772
# val part1: batch 0/59, loss 2.426, top-1 accuracy 16.000, top-5 accuracy 64.000
# val part1: loss 1.945282
# Checkpoint saved
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 2.030, top-1 accuracy 34.000, top-5 accuracy 78.000
# train part1: loss 2.049587
# val part1: batch 0/59, loss 1.840, top-1 accuracy 46.000, top-5 accuracy 90.000
# val part1: loss 1.799102
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 2.037, top-1 accuracy 38.000, top-5 accuracy 72.000
# train part1: loss 2.012847
# val part1: batch 0/59, loss 2.321, top-1 accuracy 16.000, top-5 accuracy 72.000
# val part1: loss 1.853063
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.784, top-1 accuracy 40.000, top-5 accuracy 84.000
# train part1: loss 1.918819
# val part1: batch 0/59, loss 2.004, top-1 accuracy 20.000, top-5 accuracy 90.000
# val part1: loss 1.740404
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.655, top-1 accuracy 54.000, top-5 accuracy 86.000
# train part1: loss 1.881280
# val part1: batch 0/59, loss 2.029, top-1 accuracy 26.000, top-5 accuracy 92.000
# val part1: loss 1.778705
# Checkpoint saved
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.871, top-1 accuracy 42.000, top-5 accuracy 78.000
# train part1: loss 1.858144
# val part1: batch 0/59, loss 2.073, top-1 accuracy 24.000, top-5 accuracy 78.000
# val part1: loss 1.753376
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.662, top-1 accuracy 48.000, top-5 accuracy 90.000
# train part1: loss 1.856867
# val part1: batch 0/59, loss 2.117, top-1 accuracy 28.000, top-5 accuracy 82.000
# val part1: loss 1.657026
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.631, top-1 accuracy 40.000, top-5 accuracy 94.000
# train part1: loss 1.873407
# val part1: batch 0/59, loss 2.191, top-1 accuracy 18.000, top-5 accuracy 82.000
# val part1: loss 1.590518
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.556, top-1 accuracy 50.000, top-5 accuracy 84.000
# train part1: loss 1.713181
# val part1: batch 0/59, loss 2.037, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.500988
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.738, top-1 accuracy 40.000, top-5 accuracy 86.000
# train part1: loss 1.687592
# val part1: batch 0/59, loss 1.510, top-1 accuracy 48.000, top-5 accuracy 98.000
# val part1: loss 1.448492
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.599, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.680492
# val part1: batch 0/59, loss 1.719, top-1 accuracy 34.000, top-5 accuracy 92.000
# val part1: loss 1.454456
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.789, top-1 accuracy 48.000, top-5 accuracy 78.000
# train part1: loss 1.646169
# val part1: batch 0/59, loss 2.208, top-1 accuracy 26.000, top-5 accuracy 72.000
# val part1: loss 1.490147
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.923, top-1 accuracy 36.000, top-5 accuracy 86.000
# train part1: loss 1.595892
# val part1: batch 0/59, loss 2.060, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.519088
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.250, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.565675
# val part1: batch 0/59, loss 2.194, top-1 accuracy 14.000, top-5 accuracy 78.000
# val part1: loss 1.879126
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.585, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.534763
# val part1: batch 0/59, loss 1.503, top-1 accuracy 60.000, top-5 accuracy 90.000
# val part1: loss 1.521252
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.447, top-1 accuracy 58.000, top-5 accuracy 84.000
# train part1: loss 1.452563
# val part1: batch 0/59, loss 1.673, top-1 accuracy 42.000, top-5 accuracy 90.000
# val part1: loss 1.344078
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 1.142, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.432810
# val part1: batch 0/59, loss 1.908, top-1 accuracy 28.000, top-5 accuracy 88.000
# val part1: loss 1.289051
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.658, top-1 accuracy 42.000, top-5 accuracy 86.000
# train part1: loss 1.420957
# val part1: batch 0/59, loss 1.851, top-1 accuracy 38.000, top-5 accuracy 84.000
# val part1: loss 1.310904
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.580, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.440826
# val part1: batch 0/59, loss 1.717, top-1 accuracy 36.000, top-5 accuracy 92.000
# val part1: loss 1.312577
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.277, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.349694
# val part1: batch 0/59, loss 1.985, top-1 accuracy 18.000, top-5 accuracy 84.000
# val part1: loss 1.180214
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.234, top-1 accuracy 64.000, top-5 accuracy 92.000
# train part1: loss 1.313300
# val part1: batch 0/59, loss 1.840, top-1 accuracy 30.000, top-5 accuracy 82.000
# val part1: loss 1.273597
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.282, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part1: loss 1.291305
# val part1: batch 0/59, loss 1.711, top-1 accuracy 38.000, top-5 accuracy 92.000
# val part1: loss 1.377620
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.031, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.258324
# val part1: batch 0/59, loss 2.020, top-1 accuracy 24.000, top-5 accuracy 90.000
# val part1: loss 1.195394
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.137, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.216911
# val part1: batch 0/59, loss 1.532, top-1 accuracy 44.000, top-5 accuracy 92.000
# val part1: loss 1.414781
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 0.987, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 1.111287
# val part1: batch 0/59, loss 1.819, top-1 accuracy 28.000, top-5 accuracy 90.000
# val part1: loss 1.145157
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.042, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.222887
# val part1: batch 0/59, loss 1.851, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.380957
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.042, top-1 accuracy 68.000, top-5 accuracy 96.000
# train part1: loss 1.174929
# val part1: batch 0/59, loss 0.674, top-1 accuracy 82.000, top-5 accuracy 100.000
# val part1: loss 1.449894
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 0.938, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 1.063462
# val part1: batch 0/59, loss 1.240, top-1 accuracy 62.000, top-5 accuracy 94.000
# val part1: loss 1.201662
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 0.953, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 1.067647
# val part1: batch 0/59, loss 1.356, top-1 accuracy 44.000, top-5 accuracy 100.000
# val part1: loss 1.169855
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 0.820, top-1 accuracy 74.000, top-5 accuracy 100.000
# train part1: loss 1.034231
# val part1: batch 0/59, loss 1.767, top-1 accuracy 36.000, top-5 accuracy 88.000
# val part1: loss 1.176197
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.085, top-1 accuracy 60.000, top-5 accuracy 98.000
# train part1: loss 1.075923
# val part1: batch 0/59, loss 1.035, top-1 accuracy 58.000, top-5 accuracy 100.000
# val part1: loss 1.250081
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 0.700, top-1 accuracy 76.000, top-5 accuracy 98.000
# train part1: loss 0.958608
# val part1: batch 0/59, loss 1.734, top-1 accuracy 30.000, top-5 accuracy 90.000
# val part1: loss 1.146434
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 0.917, top-1 accuracy 72.000, top-5 accuracy 90.000
# train part1: loss 0.954836
# val part1: batch 0/59, loss 1.747, top-1 accuracy 28.000, top-5 accuracy 92.000
# val part1: loss 1.254555
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 0.920, top-1 accuracy 72.000, top-5 accuracy 98.000
# train part1: loss 1.014113
# val part1: batch 0/59, loss 1.905, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.315546
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 0.859, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 0.964082
# val part1: batch 0/59, loss 1.278, top-1 accuracy 48.000, top-5 accuracy 96.000
# val part1: loss 1.213332
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.106, top-1 accuracy 68.000, top-5 accuracy 100.000
# train part1: loss 0.900427
# val part1: batch 0/59, loss 2.251, top-1 accuracy 14.000, top-5 accuracy 80.000
# val part1: loss 1.178361
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.066, top-1 accuracy 66.000, top-5 accuracy 92.000
# train part1: loss 0.850803
# val part1: batch 0/59, loss 1.310, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.108495
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.912, top-1 accuracy 68.000, top-5 accuracy 100.000
# train part1: loss 0.851264
# val part1: batch 0/59, loss 1.556, top-1 accuracy 40.000, top-5 accuracy 86.000
# val part1: loss 1.169370
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 0.781, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.841260
# val part1: batch 0/59, loss 1.468, top-1 accuracy 48.000, top-5 accuracy 92.000
# val part1: loss 1.093216
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.596, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.827810
# val part1: batch 0/59, loss 1.288, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.070031
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.810, top-1 accuracy 72.000, top-5 accuracy 100.000
# train part1: loss 0.775189
# val part1: batch 0/59, loss 0.921, top-1 accuracy 66.000, top-5 accuracy 98.000
# val part1: loss 1.524725
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 0.775, top-1 accuracy 70.000, top-5 accuracy 96.000
# train part1: loss 0.709857
# val part1: batch 0/59, loss 0.957, top-1 accuracy 62.000, top-5 accuracy 96.000
# val part1: loss 1.261353
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 0.730, top-1 accuracy 78.000, top-5 accuracy 98.000
# train part1: loss 0.777712
# val part1: batch 0/59, loss 1.595, top-1 accuracy 42.000, top-5 accuracy 88.000
# val part1: loss 1.394617
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 0.627, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.717591
# val part1: batch 0/59, loss 1.419, top-1 accuracy 46.000, top-5 accuracy 88.000
# val part1: loss 1.157158
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.915, top-1 accuracy 68.000, top-5 accuracy 96.000
# train part1: loss 0.684333
# val part1: batch 0/59, loss 1.151, top-1 accuracy 62.000, top-5 accuracy 92.000
# val part1: loss 1.355746
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 0.533, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.650421
# val part1: batch 0/59, loss 0.721, top-1 accuracy 76.000, top-5 accuracy 98.000
# val part1: loss 1.270329
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.678, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.660190
# val part1: batch 0/59, loss 2.038, top-1 accuracy 20.000, top-5 accuracy 86.000
# val part1: loss 1.179264
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.483, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.721452
# val part1: batch 0/59, loss 2.422, top-1 accuracy 20.000, top-5 accuracy 84.000
# val part1: loss 1.309595
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 0.583, top-1 accuracy 84.000, top-5 accuracy 96.000
# train part1: loss 0.681370
# val part1: batch 0/59, loss 1.417, top-1 accuracy 48.000, top-5 accuracy 86.000
# val part1: loss 1.156318
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.540, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.670764
# val part1: batch 0/59, loss 1.354, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.246445
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.406, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.616679
# val part1: batch 0/59, loss 1.581, top-1 accuracy 48.000, top-5 accuracy 88.000
# val part1: loss 1.153193
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 0.546, top-1 accuracy 84.000, top-5 accuracy 96.000
# train part1: loss 0.588246
# val part1: batch 0/59, loss 1.056, top-1 accuracy 58.000, top-5 accuracy 98.000
# val part1: loss 1.489484
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.505, top-1 accuracy 84.000, top-5 accuracy 98.000
# train part1: loss 0.497765
# val part1: batch 0/59, loss 1.450, top-1 accuracy 48.000, top-5 accuracy 92.000
# val part1: loss 1.059363
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.479, top-1 accuracy 88.000, top-5 accuracy 96.000
# train part1: loss 0.475674
# val part1: batch 0/59, loss 1.289, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.053961
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.450, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.456607
# val part1: batch 0/59, loss 1.264, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.069520
# Checkpoint saved
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.425, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.444092
# val part1: batch 0/59, loss 1.291, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.065126
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.348, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.411879
# val part1: batch 0/59, loss 1.152, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.063277
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.652, top-1 accuracy 80.000, top-5 accuracy 98.000
# train part1: loss 0.439077
# val part1: batch 0/59, loss 1.234, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.065789
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.430, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.384757
# val part1: batch 0/59, loss 1.307, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.048810
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.330, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.396477
# val part1: batch 0/59, loss 1.360, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.063634
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.282, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.399306
# val part1: batch 0/59, loss 1.261, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.075185
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.375, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.397953
# val part1: batch 0/59, loss 1.339, top-1 accuracy 48.000, top-5 accuracy 90.000
# val part1: loss 1.067044
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.575, top-1 accuracy 78.000, top-5 accuracy 100.000
# train part1: loss 0.385016
# val part1: batch 0/59, loss 1.199, top-1 accuracy 50.000, top-5 accuracy 96.000
# val part1: loss 1.080763
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.439, top-1 accuracy 82.000, top-5 accuracy 100.000
# train part1: loss 0.378764
# val part1: batch 0/59, loss 1.228, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.090090
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.336, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.343431
# val part1: batch 0/59, loss 1.270, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.083456
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.366, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.372473
# val part1: batch 0/59, loss 1.341, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.078837
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.340, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.366458
# val part1: batch 0/59, loss 1.193, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.083876
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.323, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.358552
# val part1: batch 0/59, loss 1.314, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.082528
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.336, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.370824
# val part1: batch 0/59, loss 1.288, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.092666
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.232, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.357634
# val part1: batch 0/59, loss 1.152, top-1 accuracy 52.000, top-5 accuracy 96.000
# val part1: loss 1.100708
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.308, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.343843
# val part1: batch 0/59, loss 1.376, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.085893
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.320, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.328905
# val part1: batch 0/59, loss 1.325, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.093788
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.201, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.318215
# val part1: batch 0/59, loss 1.261, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.092609
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.369, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.322468
# val part1: batch 0/59, loss 1.316, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.091750
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.309, top-1 accuracy 88.000, top-5 accuracy 98.000
# train part1: loss 0.329091
# val part1: batch 0/59, loss 1.280, top-1 accuracy 50.000, top-5 accuracy 94.000
# val part1: loss 1.110126
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.400, top-1 accuracy 84.000, top-5 accuracy 100.000
# train part1: loss 0.299104
# val part1: batch 0/59, loss 1.431, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.106963
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.287, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.319058
# val part1: batch 0/59, loss 1.241, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.117356
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.307, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.344792
# val part1: batch 0/59, loss 1.448, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.112332
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.312, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.310987
# val part1: batch 0/59, loss 1.231, top-1 accuracy 52.000, top-5 accuracy 92.000
# val part1: loss 1.104170
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.398, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.331794
# val part1: batch 0/59, loss 1.287, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.106151
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.208, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.305059
# val part1: batch 0/59, loss 1.418, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.113987
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.387, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.329037
# val part1: batch 0/59, loss 1.205, top-1 accuracy 52.000, top-5 accuracy 94.000
# val part1: loss 1.121447
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.536, top-1 accuracy 82.000, top-5 accuracy 98.000
# train part1: loss 0.317368
# val part1: batch 0/59, loss 1.574, top-1 accuracy 48.000, top-5 accuracy 90.000
# val part1: loss 1.114163
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.359, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.299202
# val part1: batch 0/59, loss 1.324, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.111513
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.584, top-1 accuracy 76.000, top-5 accuracy 100.000
# train part1: loss 0.292010
# val part1: batch 0/59, loss 1.230, top-1 accuracy 52.000, top-5 accuracy 92.000
# val part1: loss 1.121627
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.291, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.299472
# val part1: batch 0/59, loss 1.316, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.112493
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.269, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.301035
# val part1: batch 0/59, loss 1.374, top-1 accuracy 50.000, top-5 accuracy 90.000
# val part1: loss 1.111464
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.404, top-1 accuracy 92.000, top-5 accuracy 96.000
# train part1: loss 0.297892
# val part1: batch 0/59, loss 1.367, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.120183
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.249, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.303044
# val part1: batch 0/59, loss 1.392, top-1 accuracy 50.000, top-5 accuracy 92.000
# val part1: loss 1.126989
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.165, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.276733
# val part1: batch 0/59, loss 1.391, top-1 accuracy 52.000, top-5 accuracy 92.000
# val part1: loss 1.127524
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.160, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.280525
# val part1: batch 0/59, loss 1.274, top-1 accuracy 52.000, top-5 accuracy 92.000
# val part1: loss 1.138553
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.119, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.270406
# val part1: batch 0/59, loss 1.260, top-1 accuracy 52.000, top-5 accuracy 92.000
# val part1: loss 1.146958
# Checkpoint saved
# Best top-1 Accuracy = 69.916

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model and fine tune it for our purposes. This is the goal of Part 2--you will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45586014 0.45586014 0.45586014]
# std =
# [0.24808612 0.24808612 0.24808612]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45524448 0.45524448 0.45524448]
# std =
# [0.24719196 0.24719196 0.24719196]

# %% [markdown]
# Following block loads a pretrained AlexNet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify create_part2_model from student code in order to fine-tune AlexNet. As you can see in the docs (https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py) and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# Linear(in_features=4096, out_features=1000, bias=True)
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=128, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=128, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: **python -m visdom.server**. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# Setting up a new session...
# ---------------------------------------
# Experiment: part2
# n_epochs: 4
# batch_size: 10
# do_val: True
# shuffle: True
# num_workers: 4
# val_freq: 1
# print_freq: 100
# experiment: part2
# checkpoint_file: None
# resume_optim: True
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 2.682, top-1 accuracy 0.000, top-5 accuracy 60.000
# train part2: batch 100/149, loss 0.757, top-1 accuracy 80.000, top-5 accuracy 90.000
# train part2: loss 1.222762
# val part2: batch 0/298, loss 1.443, top-1 accuracy 30.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.736, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.562, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: loss 0.561482
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 0.417, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.132, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: loss 0.493316
# val part2: batch 0/298, loss 1.460, top-1 accuracy 30.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.349, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.410, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.458179
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.278, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.428, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: loss 0.374604
# val part2: batch 0/298, loss 1.957, top-1 accuracy 20.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.265, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 1.368, top-1 accuracy 60.000, top-5 accuracy 100.000
# val part2: loss 0.506881
# Checkpoint saved
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.123, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.152, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: loss 0.335377
# val part2: batch 0/298, loss 0.604, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.329, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.570, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: loss 0.387761
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# Best top-1 Accuracy = 86.533

# %% [markdown]
# Expect this code to take around 10 minutes on CPU or 30 seconds on GPU. You should hit 80% accuracy.
